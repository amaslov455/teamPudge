# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.utils import shuffle

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
df_FullHtml = pd.read_csv('/content/drive/My Drive/Colab Notebooks/html_new_1000words.csv', encoding = 'utf-8-sig')
df_FullHtml = df_FullHtml[df_FullHtml['title']!='none']
df_FullHtml = df_FullHtml[df_FullHtml['title']!='']
df_FullHtml = df_FullHtml[['category','title']].reset_index()
df_FullHtml = df_FullHtml[['category','title']]
df_FullHtml['title'] = df_FullHtml['title'].astype('str')

df_FullHtml
len(set(df_FullHtml['category']))
# Out:
# 29

# %%
df2 = df_FullHtml
df4 = df2
df2 = df4[df4['title'].str.split().str.len() > 50]
len(set(df2['category']))
# Out:
# 29

# %%
df2 = shuffle(df2)
df2 = df2.reset_index()
df2 = df2[['category','title']]

# %%
df3 = df2.groupby('category')['title'].apply(lambda row: ' '.join(row)).reset_index()

# %%
idf_vectorizer = TfidfVectorizer()
tf_idf_matrix_train = idf_vectorizer.fit_transform(df3['title'])
vectorizer = CountVectorizer()
onehot_matrix_train = vectorizer.fit_transform(df2['title'])
result_matrix_train = tf_idf_matrix_train * onehot_matrix_train.T

# %%
result_matrix_train.shape
# Out:
# (29, 87948)

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
#from sklearn.svm import LinearSVC

# %%
X = result_matrix_train.T.toarray()
y = df2['category'].to_list()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=2)

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
model = SVC(C = 1000,gamma = 0.01,kernel = 'rbf')
model.fit(X_train, y_train)
predictions = model.predict(X_test)
print(accuracy_score(y_test,predictions))
# Out:
# 0.8884333115115598

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95      1268
#            1       0.85      0.81      0.83       624
#            2       0.87      0.89      0.88      1003
#            3       0.88      0.94      0.91      3683
#            4       0.88      0.92      0.90      2629
#            5       0.95      0.90      0.93       161
#            6       0.87      0.84      0.85       371
#            7       0.91      0.89      0.90      1647
#            8       0.95      0.91      0.93       477
#            9       0.98      0.92      0.95       238
#           10       0.90      0.92      0.91      2016
#           11       0.89      0.89      0.89       283
#           12       0.93      0.92      0.93       654
#           13       0.87      0.88      0.87      1021
#           14       0.88      0.71      0.79       379
#           15       0.83      0.82      0.83      1840
#           16       0.90      0.90      0.90       879
#           17       0.84      0.81      0.82       436
#           18       0.91      0.90      0.91      2473
#           19       0.79      0.71      0.75       102
#           20       0.90      0.83      0.87       255
#           21       0.93      0.94      0.94       756
#           22       0.83      0.77      0.80       272
#           23       0.88      0.83      0.85       713
#           24       0.90      0.87      0.88      2902
#           25       0.83      0.81      0.82      1366
#           26       0.95      0.86      0.90       112
#           27       0.93      0.87      0.90       290
#           28       0.94      0.84      0.89       173
#
#     accuracy                           0.89     29023
#    macro avg       0.89      0.86      0.88     29023
# weighted avg       0.89      0.89      0.89     29023

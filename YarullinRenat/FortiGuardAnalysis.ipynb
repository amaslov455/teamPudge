# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
df = pd.read_csv('api_category.csv')

# %%
df
# Out:
#                                             url_api       service_group_id  \
# 0                 http://s104vla.storage.yandex.net            WebBrowsing
# 1             http://gb-lon-anx-r001.teamviewer.com                  Other
# 2                               http://kodikapi.com           Web_Browsing
# 3     http://brightmountainmedia-inv-eu.admixer.net           Web_Browsing
# 4                 http://s222myt.storage.yandex.net        Streaming_Audio
# ...                                             ...                    ...
# 4729          http://AT-VIE-ANX-R015.teamviewer.com  RealTimeCommunication
# 4730                  http://api.driver.360safe.com           Web_Browsing
# 4731                         http://nyaa.tracker.wf             PeerToPeer
# 4732                             http://b.wdy44.com           Web_Browsing
# 4733                           http://pki.intel.com           Web_Browsing
#
#                                category
# 0              File Sharing and Storage
# 1                         Remote Access
# 2                           Pornography
# 3                           Advertising
# 4              File Sharing and Storage
# ...                                 ...
# 4729                      Remote Access
# 4730  Information and Computer Security
# 4731                           Business
# 4732                           Business
# 4733             Information Technology
#
# [4734 rows x 3 columns]

# %%
set(df['category'])
# Out:
# {'Advertising',
#  'Armed Forces',
#  'Arts and Culture',
#  'Auction',
#  'Brokerage and Trading',
#  'Business',
#  'Child Abuse',
#  'Content Servers',
#  'Dating',
#  'Domain Parking',
#  'Dynamic Content',
#  'Dynamic DNS',
#  'Education',
#  'Entertainment',
#  'Explicit Violence',
#  'File Sharing and Storage',
#  'Finance and Banking',
#  'Folklore',
#  'Freeware and Software Downloads',
#  'Gambling',
#  'Games',
#  'General Organizations',
#  'Global Religion',
#  'Government and Legal Organizations',
#  'Hacking',
#  'Health and Wellness',
#  'Illegal or Unethical',
#  'Information Technology',
#  'Information and Computer Security',
#  'Instant Messaging',
#  'Internet Radio and TV',
#  'Internet Telephony',
#  'Job Search',
#  'Malicious Websites',
#  'Meaningless Content',
#  'Newly Observed Domain',
#  'News and Media',
#  'Newsgroups and Message Boards',
#  'Not Rated',
#  'Other Adult Materials',
#  'Peer-to-peer File Sharing',
#  'Personal Vehicles',
#  'Personal Websites and Blogs',
#  'Phishing',
#  'Political Organizations',
#  'Pornography',
#  'Proxy Avoidance',
#  'Real Estate',
#  'Reference',
#  'Remote Access',
#  'Restaurant and Dining',
#  'Search Engines and Portals',
#  'Secure Websites',
#  'Shopping',
#  'Social Networking',
#  'Society and Lifestyles',
#  'Spam URLs',
#  'Sports',
#  'Streaming Media and Download',
#  'Tobacco',
#  'Travel',
#  'Web Analytics',
#  'Web Chat',
#  'Web Hosting',
#  'Web-based Applications',
#  'Web-based Email',
#  'none'}

# %%
df_count = df['category'].value_counts()

# %%
df_count
# Out:
# Information Technology      1044
# Business                     615
# Meaningless Content          371
# File Sharing and Storage     237
# Pornography                  219
#                             ...
# Explicit Violence              1
# Armed Forces                   1
# Auction                        1
# Political Organizations        1
# Dynamic DNS                    1
# Name: category, Length: 67, dtype: int64

# %%
df_count[:10].plot(kind='bar')
